# %%
import numpy as np
import pandas as pd

# %%
## Reading the csv files
d1=pd.read_csv('ex1.csv')
d1
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
pwd
# Out:
# 'C:\\Users\\Ariya\\Examples for file reading'

# %%
#passing the absolute path
d2=pd.read_csv("C:/Users/Ariya/Examples for file reading/ex1.csv")
d2
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
## Reading tab separated file
d3=pd.read_table('test.tsv')
d3
# Out:
#             test     test   test.1   test.2   test.3
# Data        Data     Data     Data     Data     Data
# Science  Science  Science  Science  Science  Science

# %%
#Reading tab seperated file with csv
d4=pd.read_csv('test.tsv',sep='\t')
d4
# Out:
#             test     test   test.1   test.2   test.3
# Data        Data     Data     Data     Data     Data
# Science  Science  Science  Science  Science  Science

# %%
d5=pd.read_csv('ex7.csv',sep='*')
d5
# Out:
#    a  b  c
# 0  1  2  3
# 1  1  2  3

# %%
d6=pd.read_csv('ex1.csv',header=None)
d6
# Out:
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo

# %%
type(d4)
# Out:
# pandas.core.frame.DataFrame

# %%
d1.head() ## gives first 5 rows from dataframe
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
d1.tail(2) ## last 5 rows from dataframe
# Out:
#    a   b   c   d message
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
## reading row inside row
d7=pd.read_csv('csv_mindex.csv')
d7
# Out:
#   key1 key2  value1  value2
# 0  one    a       1       2
# 1  one    b       3       4
# 2  one    c       5       6
# 3  one    d       7       8
# 4  two    a       9      10
# 5  two    b      11      12
# 6  two    c      13      14
# 7  two    d      15      16

# %%
d7=pd.read_csv('csv_mindex.csv',index_col=['key1','key2'])
d7
# Out:
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16

# %%
## Skipping the unwanted rows
d8=pd.read_csv('ex4.csv',skiprows=[0,2,3])
d8
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
## Checking null or NAN or na--> considered as missing value in ML
ds_1=pd.read_csv('ex5.csv')
ds_1
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
ds_1.isnull()
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False  False   True  False    False
# 2      False  False  False  False  False    False

# %%
## getting the total number of null present in perticular column
ds_1.isnull().sum()
# Out:
# something    0
# a            0
# b            0
# c            1
# d            0
# message      1
# dtype: int64

# %%
ds_2=pd.read_csv('ex5.csv',na_values=['one']) # to replace the data with NaN values
ds_2
# Out:
#   something  a   b     c   d message
# 0       NaN  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
## Reading the excel file
d9=pd.read_excel('ex1.xlsx')
d9
# Out:
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo

# %%
d10=pd.read_excel('ex1.xlsx',sheet_name='XYA')
d10
# Out:
#    1  2  3  3.1
# 0  4  5  6    9
# 1  7  8  5    2

# %%
pwd
# Out:
# 'C:\\Users\\Ariya\\Examples for file reading'

# %%
d1=pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015.html')
d1
# Out:
# [      Eastern Conference                   W                   L  \
#  0      Atlantic Division   Atlantic Division   Atlantic Division
#  1       Toronto Raptors*                  49                  33
#  2        Boston Celtics*                  40                  42
#  3         Brooklyn Nets*                  38                  44
#  4     Philadelphia 76ers                  18                  64
#  5        New York Knicks                  17                  65
#  6       Central Division    Central Division    Central Division
#  7   Cleveland Cavaliers*                  53                  29
#  8         Chicago Bulls*                  50                  32
#  9       Milwaukee Bucks*                  41                  41
#  10        Indiana Pacers                  38                  44
#  11       Detroit Pistons                  32                  50
#  12    Southeast Division  Southeast Division  Southeast Division
# ...

# %%
d1[0]
# Out:
#       Eastern Conference                   W                   L  \
# 0      Atlantic Division   Atlantic Division   Atlantic Division
# 1       Toronto Raptors*                  49                  33
# 2        Boston Celtics*                  40                  42
# 3         Brooklyn Nets*                  38                  44
# 4     Philadelphia 76ers                  18                  64
# 5        New York Knicks                  17                  65
# 6       Central Division    Central Division    Central Division
# 7   Cleveland Cavaliers*                  53                  29
# 8         Chicago Bulls*                  50                  32
# 9       Milwaukee Bucks*                  41                  41
# 10        Indiana Pacers                  38                  44
# 11       Detroit Pistons                  32                  50
# 12    Southeast Division  Southeast Division  Southeast Division
# ...

# %%
d2=pd.read_html('https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/')
d2
# Out:
# [                         Bank NameBank           CityCity StateSt  CertCert  \
#  0                    Almena State Bank             Almena      KS     15426
#  1           First City Bank of Florida  Fort Walton Beach      FL     16748
#  2                 The First State Bank      Barboursville      WV     14361
#  3                   Ericson State Bank            Ericson      NE     18265
#  4     City National Bank of New Jersey             Newark      NJ     21111
#  ..                                 ...                ...     ...       ...
#  558                 Superior Bank, FSB           Hinsdale      IL     32646
#  559                Malta National Bank              Malta      OH      6629
#  560    First Alliance Bank & Trust Co.         Manchester      NH     34264
#  561  National State Bank of Metropolis         Metropolis      IL      3815
#  562                   Bank of Honolulu           Honolulu      HI     21029
#
# ...

# %%
d2[0]
# Out:
#                          Bank NameBank           CityCity StateSt  CertCert  \
# 0                    Almena State Bank             Almena      KS     15426
# 1           First City Bank of Florida  Fort Walton Beach      FL     16748
# 2                 The First State Bank      Barboursville      WV     14361
# 3                   Ericson State Bank            Ericson      NE     18265
# 4     City National Bank of New Jersey             Newark      NJ     21111
# ..                                 ...                ...     ...       ...
# 558                 Superior Bank, FSB           Hinsdale      IL     32646
# 559                Malta National Bank              Malta      OH      6629
# 560    First Alliance Bank & Trust Co.         Manchester      NH     34264
# 561  National State Bank of Metropolis         Metropolis      IL      3815
# 562                   Bank of Honolulu           Honolulu      HI     21029
#
# ...

# %%
type(d2)
# Out:
# list

# %%
d1[1]
# Out:
#          Western Conference                   W                   L  \
# 0        Northwest Division  Northwest Division  Northwest Division
# 1   Portland Trail Blazers*                  51                  31
# 2     Oklahoma City Thunder                  45                  37
# 3                 Utah Jazz                  38                  44
# 4            Denver Nuggets                  30                  52
# 5    Minnesota Timberwolves                  16                  66
# 6          Pacific Division    Pacific Division    Pacific Division
# 7    Golden State Warriors*                  67                  15
# 8     Los Angeles Clippers*                  56                  26
# 9              Phoenix Suns                  39                  43
# 10         Sacramento Kings                  29                  53
# 11       Los Angeles Lakers                  21                  61
# 12       Southwest Division  Southwest Division  Southwest Division
# ...

# %%
## reading json file
d3=pd.read_json('example.json')
d3
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
## saving the dataframe
D1=d2[0]
